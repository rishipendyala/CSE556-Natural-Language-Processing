# %%
import pandas as pd
import numpy as np
import pickle

# %%
# text data
df = pd.read_csv("train_df.tsv", sep="\t") 

# img descriptions
with open("D_train.pkl", "rb") as f:
    image_descriptions = pickle.load(f)
print("Image Descriptions (First 5 Records):")
for key, value in list(image_descriptions.items())[:5]:
    print(f"{key}: {value}")

print()

# detected objects
with open("O_train.pkl", "rb") as f:
    detected_objects = pickle.load(f)
print("Detected Objects (First 5 Records):")
for key, value in list(detected_objects.items())[:5]:
    print(f"{key}: {value}")
# Out:
# Image Descriptions (First 5 Records):
# 931874353976938497: people sitting on the floor in a large room with a wall
# 880425829246922752: two twee screens of donald trump and donald trump
# 690915881082343424: there are two shovels that are standing in the snow
# 915228456757059585: arafed view of a passenger plane with a flat screen tv
# 494194068998468686_25639236: cars are driving down the highway on a cloudy day
#
# Detected Objects (First 5 Records):
# 931874353976938497: {'classes': ['person', 'backpack', 'handbag', 'backpack', 'backpack', 'cell phone', 'person', 'person', 'person', 'cup', 'chair', 'person', 'person', 'person', 'person', 'person', 'person', 'person', 'person', 'person', 'chair', 'person', 'person', 'person', 'backpack', 'backpack', 'person', 'person', 'person', 'backpack', 'person', 'person', 'person', 'person', 'person', 'person'], 'confidence_scores': [0.0945774, 0.0975185, 0.111666, 0.117207, 0.118647, 0.120145, 0.121325, 0.217946, 0.224531, 0.226831, 0.280922, 0.29603, 0.338583, 0.342417, 0.345206, 0.39319, 0.414227, 0.458103, 0.46252, 0.46994, 0.560848, 0.581421, 0.591951, 0.597088, 0.614235, 0.66626, 0.672012, 0.706699, 0.722024, 0.725346, 0.774559, 0.795291, 0.842849, 0.894795, 0.895111, 0.928385]}
# 880425829246922752: {'classes': ['tv', 'book', 'person', 'person'], 'confidence_scores': [0.0566157, 0.0645416, 0.787489, 0.796628]}
# 915228456757059585: {'classes': ['tv', 'chair', 'tv', 'chair', 'chair', 'person', 'tv', 'chair', 'chair', 'tv', 'tv', 'chair', 'chair', 'tv', 'person', 'chair', 'chair', 'person', 'tv', 'person', 'person', 'tv'], 'confidence_scores': [0.0644448, 0.0680951, 0.0796244, 0.101709, 0.134147, 0.140395, 0.154054, 0.190344, 0.214901, 0.244845, 0.312947, 0.48098, 0.596227, 0.775801, 0.79419, 0.829292, 0.831051, 0.836855, 0.849639, 0.865242, 0.867333, 0.916105]}
# 494194068998468686_25639236: {'classes': ['car', 'car', 'car', 'car', 'car', 'truck', 'truck', 'car', 'truck', 'truck', 'car', 'car', 'truck', 'truck', 'car', 'car'], 'confidence_scores': [0.105599, 0.138541, 0.15192, 0.183974, 0.193817, 0.216392, 0.399908, 0.465357, 0.471086, 0.49458, 0.577627, 0.634711, 0.830119, 0.863202, 0.874461, 0.91342]}
# 886345583052681217: {'classes': ['boat', 'boat', 'boat', 'boat', 'bench', 'boat', 'boat', 'bench', 'bottle', 'boat', 'boat', 'bench', 'boat', 'chair'], 'confidence_scores': [0.0647115, 0.0925675, 0.178609, 0.269199, 0.305418, 0.328585, 0.341485, 0.358296, 0.362327, 0.450375, 0.514758, 0.572053, 0.582355, 0.91542]}

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from transformers import BartTokenizer, BartForConditionalGeneration, ViTModel
from torchvision.models import vit_b_16
from torchvision import transforms
from PIL import Image
import pandas as pd
import numpy as np
import pickle
import os
import matplotlib.pyplot as plt
import evaluate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 15
#      13 import os
#      14 import matplotlib.pyplot as plt
# ---> 15 import evaluate
#
# ModuleNotFoundError: No module named 'evaluate'

# %%
class MuSEDataset(Dataset):
    
    def __init__(self, text_file, image_desc_file, obj_file, image_folder, tokenizer, max_length=256, transform=None):
        ''' Initialize the MuSEDataset class. '''
        self.text_data = pd.read_csv(text_file, sep="\t")
        
        with open(image_desc_file, "rb") as f:
            self.image_descriptions = pickle.load(f)
        
        with open(obj_file, "rb") as f:
            self.detected_objects = pickle.load(f)
        
        self.image_folder = image_folder
        self.tokenizer = tokenizer
        self.max_length = max_length
        
        self.transform = transform if transform else transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # ImageNet normalization
            # mean and std dev for RGB channels
        ])
        
    
    def __len__(self):
        ''' Return the length of the dataset. '''
        return len(self.text_data)
    
    def __getitem__(self, idx):
        ''' Get the data for a given index.
        Here, we get:
        1. Multimodal input (txt, img desc, obj)
        2. Explanantion and target
        Tokenize them and return a dictionary of relevant data
        '''        # Get data
        row = self.text_data.iloc[idx]
        text = row["text"]  
        explanation = row["explanation"] if "explanation" in row else ""
        image_name = str(row["pid"])  # Convert to string to match dictionary keys
        sarcasm_target = str(row["target_of_sarcasm"]) if pd.notna(row.get("target_of_sarcasm", "")) else ""

        # Preprocess img
        image_path = os.path.join(self.image_folder, f"{image_name}.jpg")
        try:
            image = Image.open(image_path).convert("RGB")
            image = self.transform(image)
        except FileNotFoundError:
            # blank image if not found
            print(f"Warning: Image {image_path} not found, using blank image.")
            image = torch.zeros((3, 224, 224))

        # img desc and objects
        img_desc = self.image_descriptions.get(image_name, "No description available")
        detected_objs = self.detected_objects.get(image_name, {"classes": [], "confidence_scores": []})
        
        # formatting objs to string
        if isinstance(detected_objs, dict) and "classes" in detected_objs:
            obj_str = ", ".join(detected_objs["classes"])
        else:
            obj_str = "No objects detected"

        # multimodal input
        multimodal_text = f"Text: {text} Image: {img_desc} Objects: {obj_str}"
        
        # Tokenize inputs, explanation, target
        input_encodings = self.tokenizer(multimodal_text, padding='max_length', truncation=True, max_length=self.max_length, return_tensors="pt")
        target_encodings = self.tokenizer(explanation, padding='max_length', truncation=True, max_length=self.max_length, return_tensors="pt")
        sarcasm_target_encodings = self.tokenizer(sarcasm_target, padding='max_length', truncation=True, max_length=self.max_length, return_tensors="pt")
        
        # Return the data as a dictionary
    
        return {
            "input_ids": input_encodings["input_ids"].squeeze(0),
            "attention_mask": input_encodings["attention_mask"].squeeze(0),
            "image": image,
            "target_ids": target_encodings["input_ids"].squeeze(0),
            "target_attention_mask": target_encodings["attention_mask"].squeeze(0),
            "sarcasm_target_ids": sarcasm_target_encodings["input_ids"].squeeze(0),
            "sarcasm_target_mask": sarcasm_target_encodings["attention_mask"].squeeze(0),
            "raw_text": text,
            "raw_explanation": explanation
        }

# %%
class ImageProjection(nn.Module):
    """Projects ViT image features to match BART embedding dimensions"""
    
    def __init__(self, input_dim=768, output_dim=768):
        super().__init__()
        self.linear = nn.Linear(input_dim, output_dim)
        
    def forward(self, x):
        return self.linear(x)

class CrossModalAttention(nn.Module):
    """Computes cross-modal attention between text and vision features"""
    
    def __init__(self, feature_dim=768):
        super().__init__()
        
        self.query_v = nn.Linear(feature_dim, feature_dim)
        self.key_v = nn.Linear(feature_dim, feature_dim)
        self.value_v = nn.Linear(feature_dim, feature_dim)
        
        self.query_t = nn.Linear(feature_dim, feature_dim)
        self.key_t = nn.Linear(feature_dim, feature_dim)
        self.value_t = nn.Linear(feature_dim, feature_dim)
        
        self.dropout = nn.Dropout(0.3)
        self.scale = feature_dim ** 0.5
        
    def forward(self, vision_features, text_features):
        # self-attention for vision 
        q_v = self.query_v(vision_features)
        k_v = self.key_v(vision_features)
        v_v = self.value_v(vision_features)
        
        attn_v = torch.matmul(q_v, k_v.transpose(-2, -1)) / self.scale
        attn_v = F.softmax(attn_v, dim=-1)
        attn_v = self.dropout(attn_v)
        Av = torch.matmul(attn_v, v_v)
        
        # self-attention for text 
        q_t = self.query_t(text_features)
        k_t = self.key_t(text_features)
        v_t = self.value_t(text_features)
        
        attn_t = torch.matmul(q_t, k_t.transpose(-2, -1)) / self.scale
        attn_t = F.softmax(attn_t, dim=-1)
        attn_t = self.dropout(attn_t)
        At = torch.matmul(attn_t, v_t)
        
        # cross modal
        Ftv = At * vision_features
        Fvt = Av * text_features
        
        return Ftv, Fvt

class GatedFusion(nn.Module):
    """Gated fusion mechanism to dynamically weigh features"""
    
    def __init__(self, feature_dim=768):
        super().__init__()
        self.Wv = nn.Linear(feature_dim, feature_dim)
        self.Wt = nn.Linear(feature_dim, feature_dim)
        self.bv = nn.Parameter(torch.zeros(feature_dim))
        self.bt = nn.Parameter(torch.zeros(feature_dim))
        self.dropout = nn.Dropout(0.3)
    
    def forward(self, Ev, Et, Ftv, Fvt):
        # Gate for controlling information flow
        Gv = torch.sigmoid(self.Wv(Ev) + self.bv)
        Gt = torch.sigmoid(self.Wt(Et) + self.bt)
        
        # Multimodal features
        F1 = (Gv * Ftv) + ((1 - Gv) * Fvt)
        F2 = (Gt * Ftv) + ((1 - Gt) * Fvt)

        # Unimodal features
        Fv = (Gv * Ev) + ((1 - Gv) * Ftv)
        Ft = (Gt * Et) + ((1 - Gt) * Fvt)

        # Apply dropout
        F1 = self.dropout(F1)
        F2 = self.dropout(F2)
        Fv = self.dropout(Fv)
        Ft = self.dropout(Ft)

        return F1, F2, Fv, Ft

class SharedFusion(nn.Module):
    """Shared fusion mechanism that combines multimodal and unimodal features"""
    
    def __init__(self, feature_dim=768):
        super().__init__()
        self.alpha1 = nn.Parameter(torch.ones(1))
        self.alpha2 = nn.Parameter(torch.ones(1))
        self.beta1 = nn.Parameter(torch.ones(1))
        self.beta2 = nn.Parameter(torch.ones(1))
        self.dropout = nn.Dropout(0.3)
    
    def forward(self, F1, F2, Fv, Ft):
        # Linear combination
        FSF = self.alpha1 * F1 + self.alpha2 * F2 + self.beta1 * Fv + self.beta2 * Ft
        FSF = self.dropout(FSF)
        return FSF

class MuSEModel(nn.Module):
    """Complete MuSE model for sarcasm explanation generation"""
    
    def __init__(self, feature_dim=768, max_length=256):
        super().__init__()
        # Vision - ViT
        self.vit = vit_b_16(weights="IMAGENET1K_V1")
        self.vit.heads = nn.Identity()  # Remove classification head
        self.image_projection = ImageProjection(feature_dim, feature_dim)
        
        # Text - BART
        self.bart = BartForConditionalGeneration.from_pretrained("facebook/bart-base")
        
        # Cross-modal attention
        self.cross_modal_attention = CrossModalAttention(feature_dim)
        
        # Fusion components
        self.gated_fusion = GatedFusion(feature_dim)
        self.shared_fusion = SharedFusion(feature_dim)
        
        # Dimensions and positioning
        self.feature_dim = feature_dim
        self.max_length = max_length
        
        # Target information projection 
        self.target_projection = nn.Linear(feature_dim, feature_dim)
        # Final projection (match BART dimensions)
        self.output_projection = nn.Linear(feature_dim, feature_dim)
        
        print("Initializing MuSEModel...")
        
    def embed_text(self, input_ids, attention_mask):
        """Extract text embeddings using BART encoder"""
        encoder_outputs = self.bart.get_encoder()(  # Direct encoder access
            input_ids=input_ids,
            attention_mask=attention_mask,
            return_dict=True
        )
        return encoder_outputs.last_hidden_state
    
    def embed_image(self, images):
        """Extract image embeddings using ViT"""
        
        with torch.no_grad():
            image_features = self.vit(images)
        return self.image_projection(image_features)
        
    def forward(self, input_ids, attention_mask, images, target_ids=None, sarcasm_target_ids=None, sarcasm_target_mask=None):
        '''
        Et - text embeddings
        Ev - vision embeddings
        
        Ftv, Fvt - cross modal attention(Et,Ev)
        
        F1, F2, Fv, Ft - gated fusion(Ev, Et, Ftv, Fvt)
        FSF - shared fusion(F1, F2, Fv, Ft)
        Z - final output
        '''
        
        batch_size = input_ids.size(0)
        
        # Et is embeddings for (text + target)
        
        Et = self.embed_text(input_ids, attention_mask)
        if sarcasm_target_ids is not None and sarcasm_target_mask is not None:
            target_embed = self.embed_text(sarcasm_target_ids, sarcasm_target_mask)
            target_embed = self.target_projection(target_embed)
            Et = Et + target_embed
        
        # Ev - vision embeddings -> reshape to match text embeddings size   
        Ev = self.embed_image(images)
        Ev = Ev.unsqueeze(1).expand(-1, self.max_length, -1)
        
        # Cross-modal attention
        Ftv, Fvt = self.cross_modal_attention(Ev, Et)
        
        # Gated fusion
        F1, F2, Fv, Ft = self.gated_fusion(Ev, Et, Ftv, Fvt)
        
        # Shared fusion
        FSF = self.shared_fusion(F1, F2, Fv, Ft)
        
        # Final proj
        Z = self.output_projection(FSF) + Et 
    
        if target_ids is not None:
            
            target_length = target_ids.size(1)
            Z = Z[:, :target_length, :]
            
            # Pass to BART with proper dimensions
            outputs = self.bart(
                encoder_outputs=(Z,),
                attention_mask=attention_mask,
                labels=target_ids,
                return_dict=True
            )
            return outputs
        else:
            # Inference mode - generate text
            generated_ids = self.bart.generate(
                encoder_outputs=(Z,),  # Proper tuple format
                attention_mask=attention_mask,
                max_length=100,
                num_beams=5,
                early_stopping=True
            )
            return generated_ids

# %%
import gc
def train_one_epoch(model, dataloader, optimizer, device):
    model.train()
    total_loss = 0
    num_batches = len(dataloader)
    print(f"Total number of batches: {num_batches}")
    
    if num_batches == 0:
        raise ValueError("Dataloader is empty!")
        
    for batch_idx, batch in enumerate(dataloader):
        try:
            
            # Move data to device
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            images = batch["image"].to(device)
            target_ids = batch["target_ids"].to(device)
            sarcasm_target_ids = batch["sarcasm_target_ids"].to(device)
            sarcasm_target_mask = batch["sarcasm_target_mask"].to(device)
            
            # Zero gradients
            optimizer.zero_grad()
            
            # Forward pass
            outputs = model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                images=images,
                target_ids=target_ids,
                sarcasm_target_ids=sarcasm_target_ids,
                sarcasm_target_mask=sarcasm_target_mask
            )
            
            # Calculate loss
            loss = outputs.loss
            if batch_idx % 20 == 0:  # Print every 10 batches
                print(f"Batch {batch_idx} loss: {loss.item():.4f}")
            
            # Backward pass
            loss.backward()
            optimizer.step()
            
            total_loss += loss.item()
            
        except Exception as e:
            print(f"Error in batch {batch_idx}: {str(e)}")
            raise e
            
    avg_loss = total_loss / num_batches
    print(f"Epoch complete. Average loss: {avg_loss:.4f}")
    return avg_loss


def validate(model, dataloader, tokenizer, device, num_samples=5):
    model.eval()
    val_loss = 0
    generated_explanations = []
    reference_explanations = []
    sample_results = []
    
    with torch.no_grad():
        for idx, batch in enumerate(dataloader):
            # Move inputs to device
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            images = batch["image"].to(device)
            target_ids = batch["target_ids"].to(device)
            sarcasm_target_ids = batch["sarcasm_target_ids"].to(device)
            sarcasm_target_mask = batch["sarcasm_target_mask"].to(device)
            
            # Forward pass with teacher forcing for loss calculation
            outputs = model(
                input_ids=input_ids,
                attention_mask=attention_mask,
                images=images,
                target_ids=target_ids,
                sarcasm_target_ids=sarcasm_target_ids,
                sarcasm_target_mask=sarcasm_target_mask
            )
            
            # Get loss
            loss = outputs.loss
            val_loss += loss.item()
            
            #  get explanations
            generated_ids = model.bart.generate(
                input_ids=input_ids,
                attention_mask=attention_mask,
                max_length=100,
                num_beams=5,
                early_stopping=True
            )
            
            # decode explanations
            for i in range(input_ids.size(0)):
                gen_text = tokenizer.decode(generated_ids[i], skip_special_tokens=True)
                ref_text = tokenizer.decode(target_ids[i], skip_special_tokens=True)
                
                generated_explanations.append(gen_text)
                reference_explanations.append(ref_text)
                
                # Save sample results for display
                if len(sample_results) < num_samples:
                    original_text = batch["raw_text"][i]
                    sample_results.append({
                        "text": original_text,
                        "generated": gen_text,
                        "reference": ref_text
                    })
    
    rouge = evaluate.load("rouge")
    rouge_results = rouge.compute(
        predictions=generated_explanations,
        references=reference_explanations
    )
    
    bleu = evaluate.load("bleu")
    bleu_results = bleu.compute(
        predictions=generated_explanations,
        references=[[r] for r in reference_explanations]
    )
    
    # Calculate average loss
    avg_loss = val_loss / len(dataloader)
    
    return {
        "loss": avg_loss,
        "rouge": rouge_results,
        "bleu": bleu_results,
        "samples": sample_results[:5]
    }

def train_model(model, train_loader, val_loader, tokenizer, device, 
                 epochs, lr, checkpoint_dir="checkpoints"):
    # Create checkpoint directory if it doesn't exist
    os.makedirs(checkpoint_dir, exist_ok=True)
    
    # optimizer
    optimizer = optim.AdamW(model.parameters(), lr=lr)
    
    train_losses = []
    val_losses = []
    rouge_scores = []
    bleu_scores = []
    
    # Training loop
    for epoch in range(epochs):
        print(f"Epoch {epoch + 1}/{epochs}")
        
        # train - 1 epoch
        print(f"Training on epoch {epoch + 1}...")
        train_loss = train_one_epoch(model, train_loader, optimizer, device)
        train_losses.append(train_loss)
        print(f"Training Loss: {train_loss:.4f}")
        
        # validate
        val_results = validate(model, val_loader, tokenizer, device)
        val_losses.append(val_results["loss"])
        rouge_scores.append(val_results["rouge"]["rougeL"])
        bleu_scores.append(val_results["bleu"]["bleu"])
        
        print(f"Validation Loss: {val_results['loss']:.4f}")
        print(f"ROUGE-L: {val_results['rouge']['rougeL']:.4f}")
        print(f"BLEU: {val_results['bleu']['bleu']:.4f}")
        
        # sample results
        print("\nSample Results:")
        for i, sample in enumerate(val_results["samples"]):
            print(f"Example {i+1}:")
            print(f"Text: {sample['text']}")
            print(f"Generated: {sample['generated']}")
            print(f"Reference: {sample['reference']}")
            print()
        
        # save checkpt
        checkpoint_path = os.path.join(checkpoint_dir, f"muse_model_epoch_{epoch+1}.pt")
        torch.save({
            'epoch': epoch + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'train_loss': train_loss,
            'val_loss': val_results["loss"],
        }, checkpoint_path)
        print(f"Checkpoint saved to {checkpoint_path}")
        
        # Clear GPU memory
        torch.cuda.empty_cache()
        gc.collect()
    
    # Plot training progress
    plt.figure(figsize=(12, 4))
    
    plt.subplot(1, 3, 1)
    plt.plot(train_losses, label='Train Loss')
    plt.plot(val_losses, label='Val Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 3, 2)
    plt.plot(rouge_scores)
    plt.xlabel('Epoch')
    plt.ylabel('ROUGE-L')
    
    plt.subplot(1, 3, 3)
    plt.plot(bleu_scores)
    plt.xlabel('Epoch')
    plt.ylabel('BLEU')
    
    plt.tight_layout()
    plt.savefig(os.path.join(checkpoint_dir, 'training_progress.png'))
    plt.show()
    
    return {
        'train_losses': train_losses,
        'val_losses': val_losses,
        'rouge_scores': rouge_scores,
        'bleu_scores': bleu_scores
    }

# %%
import gc

def train_and_validate():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")
    
    seed = 42
    torch.manual_seed(seed)
    np.random.seed(seed)
    
    # BART tokenizer
    tokenizer = BartTokenizer.from_pretrained("facebook/bart-base")
    
    from torch.utils.data import Subset

    # Full training dataset
    train_dataset = MuSEDataset(
        text_file="train_df.tsv", 
        image_desc_file="D_train.pkl", 
        obj_file="O_train.pkl", 
        image_folder="images", 
        tokenizer=tokenizer
    )

    # Create a subset of the first 100 samples for training
    train_indices = list(range(100))
    train_subset = Subset(train_dataset, train_indices)

    train_size = int(0.9 * len(train_dataset))
    val_size = len(train_dataset) - train_size
    train_dataset, val_dataset = torch.utils.data.random_split(
        train_dataset, [train_size, val_size]
    )
    
    # dataloaders
    batch_size = 4
    train_loader = DataLoader(
        train_dataset, 
        batch_size=16, 
        shuffle=True, 
        num_workers=0
    )
    
    print(f"Train dataset size: {len(train_loader.dataset)}")
    print(f"Number of batches: {len(train_loader)}")
        
    val_loader = DataLoader(
        val_dataset, 
        batch_size=16, 
        shuffle=False, 
        num_workers=0
    )
    
    print(len(val_loader.dataset))

        # model
    model = MuSEModel().to(device)
    
    # train
    train_results = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        tokenizer=tokenizer,
        device=device,
        epochs=20,
        lr=1e-5,
        checkpoint_dir="checkpoints"
    )
    
    print("Training complete.")
    
    print("Saving final model...")
    
    # Save final model
    model_path = os.path.join("checkpoints", "final_model.pt")
    torch.save(model.state_dict(), model_path)
    print(f"Model saved to {model_path}")
    
    return model, train_results

def test_model(model_path="checkpoints/final_model.pt"):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Using device: {device}")
    
    # Load tokenizer
    tokenizer = BartTokenizer.from_pretrained("facebook/bart-base")
    
    # Load model
    model = MuSEModel().to(device)
    model.load_state_dict(torch.load(model_path))
    model.eval()
    
    # Load test data
    test_dataset = MuSEDataset(
        text_file="test_df.tsv", 
        image_desc_file="D_test.pkl", 
        obj_file="O_test.pkl", 
        image_folder="images", 
        tokenizer=tokenizer
    )
    
    test_loader = DataLoader(
        test_dataset, 
        batch_size=16, 
        shuffle=False, 
        num_workers=0
    )
    
    # Evaluate
    test_results = validate(model, test_loader, tokenizer, device)
    
    # Save predictions
    predictions = []
    with torch.no_grad():
        for batch in test_loader:
            outputs = model.generate(
                input_ids=batch['input_ids'].to(device),
                attention_mask=batch['attention_mask'].to(device),
                max_length=50
            )
            preds = tokenizer.batch_decode(outputs, skip_special_tokens=True)
            predictions.extend(preds)
    
    with open("test_predictions.txt", "w") as f:
        for pred in predictions:
            f.write(pred + "\n")
    
    print("\nTest Results:")
    print(f"Loss: {test_results['loss']:.4f}")
    print(f"ROUGE-1: {test_results['rouge']['rouge1']:.4f}")
    print(f"ROUGE-2: {test_results['rouge']['rouge2']:.4f}")
    print(f"ROUGE-L: {test_results['rouge']['rougeL']:.4f}")
    print(f"BLEU: {test_results['bleu']['bleu']:.4f}")
    
    return test_results

# %%
model, train_results = train_and_validate()
# Out:
# Using device: cuda
# Train dataset size: 2684
# Number of batches: 671
# 299
# Initializing MuSEModel...
# Epoch 1/20
# Training on epoch 1...
# Total number of batches: 671
# Batch 0 loss: 16.9806
# Batch 20 loss: 4.7691
# Batch 40 loss: 0.7860
# Batch 60 loss: 0.6947
# Batch 80 loss: 0.3760
# Batch 100 loss: 0.4047
# Batch 120 loss: 0.3121
# Batch 140 loss: 0.3554
# Batch 160 loss: 0.1742
# Batch 180 loss: 0.3327
# Batch 200 loss: 0.4401
# Batch 220 loss: 0.3416
# Batch 240 loss: 0.2420
# Batch 260 loss: 0.2295
# Batch 280 loss: 0.3549
# Batch 300 loss: 0.4144
# Batch 320 loss: 0.3338
# Batch 340 loss: 0.3659
# Batch 360 loss: 0.2192
# Batch 380 loss: 0.2055
# Batch 400 loss: 0.1109
# Batch 420 loss: 0.2201
# Batch 440 loss: 0.2317
# Batch 460 loss: 0.1892
# Batch 480 loss: 0.2137
# Batch 500 loss: 0.1499
# Batch 520 loss: 0.1058
# Batch 540 loss: 0.1940
# Batch 560 loss: 0.0972
# Batch 580 loss: 0.0825
# Batch 600 loss: 0.1203
# Batch 620 loss: 0.1533
# Batch 640 loss: 0.1214
# Batch 660 loss: 0.2441
# Epoch complete. Average loss: 0.5917
# Training Loss: 0.5917
# Validation Loss: 0.1402
# ROUGE-L: 0.4078
# BLEU: 0.2685
#
# Sample Results:
# Example 1:
# Text: 'menu testing with all of the duck ! this is the hard part . # toughwork  # menu # brewpub # openingsoon'
# Generated: the author is pissed at <user> for not compromising the environment with all of the duck.
# Reference: menu testing with all of the duck isn't the hard part, it's fun.
#
# Example 2:
# Text: 'oh great , sky lanterns are sold for all seasons and holidays now ! i just love picking up these ! <user>  # skytrash'
# Generated: the author doesn't care if sky lanterns are sold for all seasons and holidays now.
# Reference: the author hates that sky lanterns are sold for all seasons and holidays now, it's inconvenient picking them up.
#
# Example 3:
# Text: 'so weather conditions are affecting <user> services . it does look dreadful outside ! ! ! # redhillmoo '
# Generated: the author is sad that weather conditions are affecting <user> services, it does look dreadful outside.
# Reference: <user> says weather conditions are affecting their services, but outside looks pretty pleasant to author.
#
# Example 4:
# Text: '<user> <user> nothing says fun like getting ready for a raid at 5:30 in the morning . '
# Generated: the author is pissed at <user> for getting ready for a raid at 5:30 in the morning.
# Reference: it's not fun getting ready for a raid at 5:30 in the morning.
#
# Example 5:
# Text: 'yeah $ 226 is great ! now i can buy the new # lebrons with all my # profit ... because '
# Generated: the author is pissed at <user> for not saving the new lebrons with all her profit.
# Reference: the author isn't satisfied with $ 226 since he can't buy the new lebrons with all his profit.
#
# Checkpoint saved to checkpoints\muse_model_epoch_1.pt
# Epoch 2/20
# Training on epoch 2...
# Total number of batches: 671
# Batch 0 loss: 0.0564
# Batch 20 loss: 0.1417
# Batch 40 loss: 0.1048
# Batch 60 loss: 0.0793
# Batch 80 loss: 0.1552
# Batch 100 loss: 0.1860
# Batch 120 loss: 0.1132
# Batch 140 loss: 0.1786
# Batch 160 loss: 0.1739
# Batch 180 loss: 0.1155
# Batch 200 loss: 0.0961
# Batch 220 loss: 0.0537
# Batch 240 loss: 0.0826
# Batch 260 loss: 0.1658
# Batch 280 loss: 0.1490
# Batch 300 loss: 0.1826
# Batch 320 loss: 0.1035
# Batch 340 loss: 0.1917
# Batch 360 loss: 0.0604
# Batch 380 loss: 0.0731
# Batch 400 loss: 0.0734
# Batch 420 loss: 0.1285
# Batch 440 loss: 0.0861
# Batch 460 loss: 0.1182
# Batch 480 loss: 0.1770
# Batch 500 loss: 0.0965
# Batch 520 loss: 0.0646
# Batch 540 loss: 0.1272
# Batch 560 loss: 0.1106
# Batch 580 loss: 0.0680
# Batch 600 loss: 0.1020
# Batch 620 loss: 0.0609
# Batch 640 loss: 0.1677
# Batch 660 loss: 0.0952
# Epoch complete. Average loss: 0.1186
# Training Loss: 0.1186
# Validation Loss: 0.1319
# ROUGE-L: 0.4114
# BLEU: 0.2758
#
# Sample Results:
# Example 1:
# Text: 'menu testing with all of the duck ! this is the hard part . # toughwork  # menu # brewpub # openingsoon'
# Generated: the author is pissed at <user> for such error testing with all of the duck.
# Reference: menu testing with all of the duck isn't the hard part, it's fun.
#
# Example 2:
# Text: 'oh great , sky lanterns are sold for all seasons and holidays now ! i just love picking up these ! <user>  # skytrash'
# Generated: the author is pissed at <user> since sky lanterns are sold for all seasons and holidays.
# Reference: the author hates that sky lanterns are sold for all seasons and holidays now, it's inconvenient picking them up.
#
# Example 3:
# Text: 'so weather conditions are affecting <user> services . it does look dreadful outside ! ! ! # redhillmoo '
# Generated: the author is pissed at <user> for such bad weather conditions.
# Reference: <user> says weather conditions are affecting their services, but outside looks pretty pleasant to author.
#
# Example 4:
# Text: '<user> <user> nothing says fun like getting ready for a raid at 5:30 in the morning . '
# Generated: the author is pissed at <user> for getting ready for a raid at 5:30 in the morning.
# Reference: it's not fun getting ready for a raid at 5:30 in the morning.
#
# Example 5:
# Text: 'yeah $ 226 is great ! now i can buy the new # lebrons with all my # profit ... because '
# Generated: the author is pissed at <user> for not buying the new lebrons with all her profit.
# Reference: the author isn't satisfied with $ 226 since he can't buy the new lebrons with all his profit.
#
# Checkpoint saved to checkpoints\muse_model_epoch_2.pt
# Epoch 3/20
# Training on epoch 3...
# Total number of batches: 671
# Batch 0 loss: 0.1257
# Batch 20 loss: 0.0820
# Batch 40 loss: 0.1691
# Batch 60 loss: 0.0882
# Batch 80 loss: 0.0577
# Batch 100 loss: 0.0711
# Batch 120 loss: 0.0690
# Batch 140 loss: 0.1061
# Batch 160 loss: 0.0853
# Batch 180 loss: 0.0492
# Batch 200 loss: 0.0932
# Batch 220 loss: 0.0785
# Batch 240 loss: 0.0475
# Batch 260 loss: 0.0899
# Batch 280 loss: 0.0726
# Batch 300 loss: 0.1125
# Batch 320 loss: 0.0793
# Batch 340 loss: 0.1071
# Batch 360 loss: 0.0638
# Batch 380 loss: 0.1985
# Batch 400 loss: 0.1105
# Batch 420 loss: 0.1257
# Batch 440 loss: 0.1216
# Batch 460 loss: 0.1322
# Batch 480 loss: 0.1871
# Batch 500 loss: 0.1014
# Batch 520 loss: 0.0887
# Batch 540 loss: 0.0796
# Batch 560 loss: 0.1105
# Batch 580 loss: 0.1172
# Batch 600 loss: 0.1398
# Batch 620 loss: 0.0590
# Batch 640 loss: 0.0831
# Batch 660 loss: 0.1869
# Epoch complete. Average loss: 0.0961
# Training Loss: 0.0961
# Validation Loss: 0.1329
# ROUGE-L: 0.3682
# BLEU: 0.2240
#
# Sample Results:
# Example 1:
# Text: 'menu testing with all of the duck ! this is the hard part . # toughwork  # menu # brewpub # openingsoon'
# Generated: this isn't the hard part.
# Reference: menu testing with all of the duck isn't the hard part, it's fun.
#
# Example 2:
# Text: 'oh great , sky lanterns are sold for all seasons and holidays now ! i just love picking up these ! <user>  # skytrash'
# Generated: the author is pissed at <user> since sky lanterns are sold for all seasons and holidays.
# Reference: the author hates that sky lanterns are sold for all seasons and holidays now, it's inconvenient picking them up.
#
# Example 3:
# Text: 'so weather conditions are affecting <user> services . it does look dreadful outside ! ! ! # redhillmoo '
# Generated: weather conditions aren't affecting <user>.
# Reference: <user> says weather conditions are affecting their services, but outside looks pretty pleasant to author.
#
# Example 4:
# Text: '<user> <user> nothing says fun like getting ready for a raid at 5:30 in the morning . '
# Generated: nobody likes getting ready for a raid at 5:30 in the morning.
# Reference: it's not fun getting ready for a raid at 5:30 in the morning.
#
# Example 5:
# Text: 'yeah $ 226 is great ! now i can buy the new # lebrons with all my # profit ... because '
# Generated: the author doesn't need $ 226 to buy the new lebrons.
# Reference: the author isn't satisfied with $ 226 since he can't buy the new lebrons with all his profit.
#
# Checkpoint saved to checkpoints\muse_model_epoch_3.pt
# Epoch 4/20
# Training on epoch 4...
# Total number of batches: 671
# Batch 0 loss: 0.0658
# Batch 20 loss: 0.0735
# Batch 40 loss: 0.0829
# Batch 60 loss: 0.0747
# Batch 80 loss: 0.0647
# Batch 100 loss: 0.0380
# Batch 120 loss: 0.0910
# Batch 140 loss: 0.0935
# Batch 160 loss: 0.0386
# Batch 180 loss: 0.0465
# Batch 200 loss: 0.0980
# Batch 220 loss: 0.0857
# Batch 240 loss: 0.0558
# Batch 260 loss: 0.0450
# Batch 280 loss: 0.0578
# Batch 300 loss: 0.0242
# Batch 320 loss: 0.0646
# Batch 340 loss: 0.0395
# Batch 360 loss: 0.1438
# Batch 380 loss: 0.0456
# Batch 400 loss: 0.0784
# Batch 420 loss: 0.0651
# Batch 440 loss: 0.0979
# Batch 460 loss: 0.0366
# Batch 480 loss: 0.0438
# Batch 500 loss: 0.1085
# Batch 520 loss: 0.0603
# Batch 540 loss: 0.0888
# Batch 560 loss: 0.0529
# Batch 580 loss: 0.0701
# Batch 600 loss: 0.0370
# Batch 620 loss: 0.0815
# Batch 640 loss: 0.0600
# Batch 660 loss: 0.0560
# Epoch complete. Average loss: 0.0708
# Training Loss: 0.0708
# Validation Loss: 0.1406
# ROUGE-L: 0.3393
# BLEU: 0.2256
#
# Sample Results:
# Example 1:
# Text: 'menu testing with all of the duck ! this is the hard part . # toughwork  # menu # brewpub # openingsoon'
# Generated: the author is pissed at <user> for not doing enough work with all of the duck.
# Reference: menu testing with all of the duck isn't the hard part, it's fun.
#
# Example 2:
# Text: 'oh great , sky lanterns are sold for all seasons and holidays now ! i just love picking up these ! <user>  # skytrash'
# Generated: the author doesn't care if sky lanterns are sold for all seasons and holidays.
# Reference: the author hates that sky lanterns are sold for all seasons and holidays now, it's inconvenient picking them up.
#
# Example 3:
# Text: 'so weather conditions are affecting <user> services . it does look dreadful outside ! ! ! # redhillmoo '
# Generated: weather conditions aren't affecting <user> services.
# Reference: <user> says weather conditions are affecting their services, but outside looks pretty pleasant to author.
#
# Example 4:
# Text: '<user> <user> nothing says fun like getting ready for a raid at 5:30 in the morning . '
# Generated: the author is pissed at <user> for getting ready for a raid at 5:30 in the morning.
# Reference: it's not fun getting ready for a raid at 5:30 in the morning.
#
# Example 5:
# Text: 'yeah $ 226 is great ! now i can buy the new # lebrons with all my # profit ... because '
# Generated: the author is pissed at <user> for not delivering the new lebrons with all her profit.
# Reference: the author isn't satisfied with $ 226 since he can't buy the new lebrons with all his profit.
#
# Checkpoint saved to checkpoints\muse_model_epoch_4.pt
# Epoch 5/20
# Training on epoch 5...
# Total number of batches: 671
# Batch 0 loss: 0.0384
# Batch 20 loss: 0.0520
# Batch 40 loss: 0.0657
# Batch 60 loss: 0.0496
# Batch 80 loss: 0.0387
# Batch 100 loss: 0.0460
# Batch 120 loss: 0.0455
# Batch 140 loss: 0.0285
# Batch 160 loss: 0.0995
# Batch 180 loss: 0.0685
# Batch 200 loss: 0.1467
# Batch 220 loss: 0.0574
# Batch 240 loss: 0.0802
# Batch 260 loss: 0.0534
# Batch 280 loss: 0.0325
# Batch 300 loss: 0.0751
# Batch 320 loss: 0.0301
# Batch 340 loss: 0.0329
# Batch 360 loss: 0.0474
# Batch 380 loss: 0.0499
# Batch 400 loss: 0.0478
# Batch 420 loss: 0.0544
# Batch 440 loss: 0.0375
# Batch 460 loss: 0.0809
# Batch 480 loss: 0.0729
# Batch 500 loss: 0.0635
# Batch 520 loss: 0.0245
# Batch 540 loss: 0.0536
# Batch 560 loss: 0.0604
# Batch 580 loss: 0.0558
# Batch 600 loss: 0.0291
# Batch 620 loss: 0.0684
# Batch 640 loss: 0.0755
# Batch 660 loss: 0.0457
# Epoch complete. Average loss: 0.0559
# Training Loss: 0.0559
# Validation Loss: 0.1486
# ROUGE-L: 0.3862
# BLEU: 0.2523
#
# Sample Results:
# Example 1:
# Text: 'menu testing with all of the duck ! this is the hard part . # toughwork  # menu # brewpub # openingsoon'
# Generated: the author doesn't want to have to do a menu testing with all of the duck.
# Reference: menu testing with all of the duck isn't the hard part, it's fun.
#
# Example 2:
# Text: 'oh great , sky lanterns are sold for all seasons and holidays now ! i just love picking up these ! <user>  # skytrash'
# Generated: the author doesn't care if sky lanterns are sold for all seasons and holidays.
# Reference: the author hates that sky lanterns are sold for all seasons and holidays now, it's inconvenient picking them up.
#
# Example 3:
# Text: 'so weather conditions are affecting <user> services . it does look dreadful outside ! ! ! # redhillmoo '
# Generated: weather conditions aren't affecting <user> services.
# Reference: <user> says weather conditions are affecting their services, but outside looks pretty pleasant to author.
#
# Example 4:
# Text: '<user> <user> nothing says fun like getting ready for a raid at 5:30 in the morning . '
# Generated: the author doesn't like getting ready for a raid at 5:30 in the morning.
# Reference: it's not fun getting ready for a raid at 5:30 in the morning.
#
# Example 5:
# Text: 'yeah $ 226 is great ! now i can buy the new # lebrons with all my # profit ... because '
# Generated: the author doesn't want to have to buy the new lebrons with all her profit.
# Reference: the author isn't satisfied with $ 226 since he can't buy the new lebrons with all his profit.
#
# Checkpoint saved to checkpoints\muse_model_epoch_5.pt
# Epoch 6/20
# Training on epoch 6...
# Total number of batches: 671
# Batch 0 loss: 0.0407
# Batch 20 loss: 0.0417
# Batch 40 loss: 0.0256
# Batch 60 loss: 0.1049
# Batch 80 loss: 0.0293
# Batch 100 loss: 0.0374
# Batch 120 loss: 0.0496
# Batch 140 loss: 0.0352
# Batch 160 loss: 0.0505
# Batch 180 loss: 0.0366
# Batch 200 loss: 0.0682
# Batch 220 loss: 0.0489
# Batch 240 loss: 0.0362
# Batch 260 loss: 0.0747
# Batch 280 loss: 0.0466
# Batch 300 loss: 0.0350
# Batch 320 loss: 0.0400
# Batch 340 loss: 0.0536
# Batch 360 loss: 0.0554
# Batch 380 loss: 0.0355
# Batch 400 loss: 0.0526
# Batch 420 loss: 0.0225
# Batch 440 loss: 0.0539
# Batch 460 loss: 0.0309
# Batch 480 loss: 0.0451
# Batch 500 loss: 0.0539
# Batch 520 loss: 0.0266
# Batch 540 loss: 0.0429
# Batch 560 loss: 0.0416
# Batch 580 loss: 0.0481
# Batch 600 loss: 0.0589
# Batch 620 loss: 0.0351
# Batch 640 loss: 0.0816
# Batch 660 loss: 0.0418
# Epoch complete. Average loss: 0.0529
# Training Loss: 0.0529
# Validation Loss: 0.1577
# ROUGE-L: 0.4128
# BLEU: 0.2684
#
# Sample Results:
# Example 1:
# Text: 'menu testing with all of the duck ! this is the hard part . # toughwork  # menu # brewpub # openingsoon'
# Generated: menu testing with all of the duck isn't the hard part.
# Reference: menu testing with all of the duck isn't the hard part, it's fun.
#
# Example 2:
# Text: 'oh great , sky lanterns are sold for all seasons and holidays now ! i just love picking up these ! <user>  # skytrash'
# Generated: the author is pissed at <user> that sky lanterns are sold for all seasons and holidays and he doesn't love picking up these.
# Reference: the author hates that sky lanterns are sold for all seasons and holidays now, it's inconvenient picking them up.
#
# Example 3:
# Text: 'so weather conditions are affecting <user> services . it does look dreadful outside ! ! ! # redhillmoo '
# Generated: weather conditions aren't affecting <user> services, it does look dreadful outside.
# Reference: <user> says weather conditions are affecting their services, but outside looks pretty pleasant to author.
#
# Example 4:
# Text: '<user> <user> nothing says fun like getting ready for a raid at 5:30 in the morning . '
# Generated: it's inconvenient to get ready for a raid at 5:30 in the morning.
# Reference: it's not fun getting ready for a raid at 5:30 in the morning.
#
# Example 5:
# Text: 'yeah $ 226 is great ! now i can buy the new # lebrons with all my # profit ... because '
# Generated: $ 226 is a huge difference, not a significant saving.
# Reference: the author isn't satisfied with $ 226 since he can't buy the new lebrons with all his profit.
#
# Checkpoint saved to checkpoints\muse_model_epoch_6.pt
# Epoch 7/20
# Training on epoch 7...
# Total number of batches: 671
# Batch 0 loss: 0.0292
# Batch 20 loss: 0.0319
# Batch 40 loss: 0.0224
# Batch 60 loss: 0.0329
# Batch 80 loss: 0.0182
# Batch 100 loss: 0.0596
# Batch 120 loss: 0.0288
# Batch 140 loss: 0.0161
# Batch 160 loss: 0.0288
# Batch 180 loss: 0.0281
# Batch 200 loss: 0.0155
# Batch 220 loss: 0.0271
# Batch 240 loss: 0.0338
# Batch 260 loss: 0.0251
# Batch 280 loss: 0.0134
# Batch 300 loss: 0.0192
# Batch 320 loss: 0.0567
# Batch 340 loss: 0.0253
# Batch 360 loss: 0.0109
# Batch 380 loss: 0.0361
# Batch 400 loss: 0.0231
# Batch 420 loss: 0.0260
# Batch 440 loss: 0.0276
# Batch 460 loss: 0.0411
# Batch 480 loss: 0.0299
# Batch 500 loss: 0.0545
# Batch 520 loss: 0.0268
# Batch 540 loss: 0.0182
# Batch 560 loss: 0.0402
# Batch 580 loss: 0.0339
# Batch 600 loss: 0.0248
# Batch 620 loss: 0.0514
# Batch 640 loss: 0.0473
# Batch 660 loss: 0.0349
# Epoch complete. Average loss: 0.0327
# Training Loss: 0.0327
# Validation Loss: 0.1897
# ROUGE-L: 0.3389
# BLEU: 0.2138
#
# Sample Results:
# Example 1:
# Text: 'menu testing with all of the duck ! this is the hard part . # toughwork  # menu # brewpub # openingsoon'
# Generated: the author is pissed at <user> for not disclosing meetings with all of the ducks.
# Reference: menu testing with all of the duck isn't the hard part, it's fun.
#
# Example 2:
# Text: 'oh great , sky lanterns are sold for all seasons and holidays now ! i just love picking up these ! <user>  # skytrash'
# Generated: the author hates that sky lanterns are sold for all seasons and holidays.
# Reference: the author hates that sky lanterns are sold for all seasons and holidays now, it's inconvenient picking them up.
#
# Example 3:
# Text: 'so weather conditions are affecting <user> services . it does look dreadful outside ! ! ! # redhillmoo '
# Generated: weather conditions aren't affecting <user> services.
# Reference: <user> says weather conditions are affecting their services, but outside looks pretty pleasant to author.
#
# Example 4:
# Text: '<user> <user> nothing says fun like getting ready for a raid at 5:30 in the morning . '
# Generated: getting ready for a raid at 5:30 in the morning isn't fun.
# Reference: it's not fun getting ready for a raid at 5:30 in the morning.
#
# Example 5:
# Text: 'yeah $ 226 is great ! now i can buy the new # lebrons with all my # profit ... because '
# Generated: $ 226 isn't a significant discount, it's inappropriate to buy the new lebrons with such profanity on it.
# Reference: the author isn't satisfied with $ 226 since he can't buy the new lebrons with all his profit.
#
# Checkpoint saved to checkpoints\muse_model_epoch_7.pt
# Epoch 8/20
# Training on epoch 8...
# Total number of batches: 671
# Batch 0 loss: 0.0520
# Batch 20 loss: 0.0475
# Batch 40 loss: 0.0824
# Batch 60 loss: 0.0492
# Batch 80 loss: 0.0232
# Batch 100 loss: 0.0297
# Batch 120 loss: 0.0213
# Batch 140 loss: 0.0168
# Batch 160 loss: 0.0406
# Batch 180 loss: 0.0146
# Batch 200 loss: 0.0249
# Batch 220 loss: 0.0266
# Batch 240 loss: 0.0158
# Batch 260 loss: 0.0587
# Batch 280 loss: 0.0286
# Batch 300 loss: 0.0377
# Batch 320 loss: 0.0333
# Batch 340 loss: 0.0274
# Batch 360 loss: 0.0188
# Batch 380 loss: 0.0335
# Batch 400 loss: 0.0444
# Batch 420 loss: 0.0295
# Batch 440 loss: 0.0414
# Batch 460 loss: 0.0215
# Batch 480 loss: 0.0138
# Batch 500 loss: 0.0233
# Batch 520 loss: 0.0161
# Batch 540 loss: 0.0412
# Batch 560 loss: 0.0146
# Batch 580 loss: 0.0293
# Batch 600 loss: 0.0272
# Batch 620 loss: 0.0188
# Batch 640 loss: 0.0166
# Batch 660 loss: 0.0088
# Epoch complete. Average loss: 0.0299
# Training Loss: 0.0299
# Validation Loss: 0.1758
# ROUGE-L: 0.3595
# BLEU: 0.2121
#
# Sample Results:
# Example 1:
# Text: 'menu testing with all of the duck ! this is the hard part . # toughwork  # menu # brewpub # openingsoon'
# Generated: the author is pissed at <user> for such difficult work with all of the duck.
# Reference: menu testing with all of the duck isn't the hard part, it's fun.
#
# Example 2:
# Text: 'oh great , sky lanterns are sold for all seasons and holidays now ! i just love picking up these ! <user>  # skytrash'
# Generated: the author is pissed at <user> since sky lanterns are sold for all seasons and holidays.
# Reference: the author hates that sky lanterns are sold for all seasons and holidays now, it's inconvenient picking them up.
#
# Example 3:
# Text: 'so weather conditions are affecting <user> services . it does look dreadful outside ! ! ! # redhillmoo '
# Generated: weather conditions aren't affecting <user> services, it does look dreadful outside.
# Reference: <user> says weather conditions are affecting their services, but outside looks pretty pleasant to author.
#
# Example 4:
# Text: '<user> <user> nothing says fun like getting ready for a raid at 5:30 in the morning . '
# Generated: getting ready for a raid at 5:30 in the morning isn't fun.
# Reference: it's not fun getting ready for a raid at 5:30 in the morning.
#
# Example 5:
# Text: 'yeah $ 226 is great ! now i can buy the new # lebrons with all my # profit ... because '
# Generated: the author is pissed at <user> for having to stand while people are waiting.
# Reference: the author isn't satisfied with $ 226 since he can't buy the new lebrons with all his profit.
#
# Checkpoint saved to checkpoints\muse_model_epoch_8.pt
# Epoch 9/20
# Training on epoch 9...
# Total number of batches: 671
# Batch 0 loss: 0.0189
# Batch 20 loss: 0.0058
# Batch 40 loss: 0.0246
# Batch 60 loss: 0.0171
# Batch 80 loss: 0.0146
# Batch 100 loss: 0.0175
# Batch 120 loss: 0.0073
# Batch 140 loss: 0.0144
# Batch 160 loss: 0.0275
# Batch 180 loss: 0.0330
# Batch 200 loss: 0.0157
# Batch 220 loss: 0.0158
# Batch 240 loss: 0.0116
# Batch 260 loss: 0.0177
# Batch 280 loss: 0.0076
# Batch 300 loss: 0.0092
# Batch 320 loss: 0.0193
# Batch 340 loss: 0.0208
# Batch 360 loss: 0.0187
# Batch 380 loss: 0.0235
# Batch 400 loss: 0.0127
# Batch 420 loss: 0.0187
# Batch 440 loss: 0.0121
# Batch 460 loss: 0.0281
# Batch 480 loss: 0.0262
# Batch 500 loss: 0.0148
# Batch 520 loss: 0.0262
# Batch 540 loss: 0.0223
# Batch 560 loss: 0.0144
# Batch 580 loss: 0.0080
# Batch 600 loss: 0.0338
# Batch 620 loss: 0.1930
# Batch 640 loss: 0.0353
# Batch 660 loss: 0.0288
# Epoch complete. Average loss: 0.0205
# Training Loss: 0.0205
# Validation Loss: 0.1907
# ROUGE-L: 0.4266
# BLEU: 0.2699
#
# Sample Results:
# Example 1:
# Text: 'menu testing with all of the duck ! this is the hard part . # toughwork  # menu # brewpub # openingsoon'
# Generated: menu testing with all of the duck isn't the hard part.
# Reference: menu testing with all of the duck isn't the hard part, it's fun.
#
# Example 2:
# Text: 'oh great , sky lanterns are sold for all seasons and holidays now ! i just love picking up these ! <user>  # skytrash'
# Generated: the author hates that sky lanterns are sold for all seasons and holidays.
# Reference: the author hates that sky lanterns are sold for all seasons and holidays now, it's inconvenient picking them up.
#
# Example 3:
# Text: 'so weather conditions are affecting <user> services . it does look dreadful outside ! ! ! # redhillmoo '
# Generated: weather conditions aren't affecting <user> services, it does look good outside.
# Reference: <user> says weather conditions are affecting their services, but outside looks pretty pleasant to author.
#
# Example 4:
# Text: '<user> <user> nothing says fun like getting ready for a raid at 5:30 in the morning . '
# Generated: getting ready for a raid at 5:30 in the morning is frustrating.
# Reference: it's not fun getting ready for a raid at 5:30 in the morning.
#
# Example 5:
# Text: 'yeah $ 226 is great ! now i can buy the new # lebrons with all my # profit ... because '
# Generated: $ 226 isn't great, the author has to buy the new lebrons with all her profit.
# Reference: the author isn't satisfied with $ 226 since he can't buy the new lebrons with all his profit.
#
# Checkpoint saved to checkpoints\muse_model_epoch_9.pt
# Epoch 10/20
# Training on epoch 10...
# Total number of batches: 671
# Batch 0 loss: 0.0063
# Batch 20 loss: 0.0187
# Batch 40 loss: 0.0070
# Batch 60 loss: 0.0106
# Batch 80 loss: 0.1083
# Batch 100 loss: 0.0499
# Batch 120 loss: 0.0309
# Batch 140 loss: 0.0347
# Batch 160 loss: 0.0235
# Batch 180 loss: 0.0169
# Batch 200 loss: 0.0228
# Batch 220 loss: 0.0218
# Batch 240 loss: 0.0275
# Batch 260 loss: 0.0500
# Batch 280 loss: 0.0509
# Batch 300 loss: 0.0180
# Batch 320 loss: 0.0270
# Batch 340 loss: 0.0192
# Batch 360 loss: 0.0170
# Batch 380 loss: 0.0193
# Batch 400 loss: 0.0159
# Batch 420 loss: 0.0265
# Batch 440 loss: 0.0270
# Batch 460 loss: 0.0333
# Batch 480 loss: 0.0264
# Batch 500 loss: 0.0316
# Batch 520 loss: 0.0135
# Batch 540 loss: 0.0380
# Batch 560 loss: 0.0144
# Batch 580 loss: 0.0183
# Batch 600 loss: 0.0294
# Batch 620 loss: 0.0260
# Batch 640 loss: 0.0087
# Batch 660 loss: 0.0178
# Epoch complete. Average loss: 0.0265
# Training Loss: 0.0265
# Validation Loss: 0.1936
# ROUGE-L: 0.3879
# BLEU: 0.2398
#
# Sample Results:
# Example 1:
# Text: 'menu testing with all of the duck ! this is the hard part . # toughwork  # menu # brewpub # openingsoon'
# Generated: menu testing with all of the duck isn't the hard part of the author.
# Reference: menu testing with all of the duck isn't the hard part, it's fun.
#
# Example 2:
# Text: 'oh great , sky lanterns are sold for all seasons and holidays now ! i just love picking up these ! <user>  # skytrash'
# Generated: the author is pissed at <user> since sky lanterns are sold for all seasons and holidays.
# Reference: the author hates that sky lanterns are sold for all seasons and holidays now, it's inconvenient picking them up.
#
# Example 3:
# Text: 'so weather conditions are affecting <user> services . it does look dreadful outside ! ! ! # redhillmoo '
# Generated: weather conditions aren't affecting <user> services.
# Reference: <user> says weather conditions are affecting their services, but outside looks pretty pleasant to author.
#
# Example 4:
# Text: '<user> <user> nothing says fun like getting ready for a raid at 5:30 in the morning . '
# Generated: the author doesn't like getting ready for a raid at 5:30 in the morning.
# Reference: it's not fun getting ready for a raid at 5:30 in the morning.
#
# Example 5:
# Text: 'yeah $ 226 is great ! now i can buy the new # lebrons with all my # profit ... because '
# Generated: $ 226 isn't a great bargain, the author has to buy the new lebrons with all her profit.
# Reference: the author isn't satisfied with $ 226 since he can't buy the new lebrons with all his profit.
#
# Checkpoint saved to checkpoints\muse_model_epoch_10.pt
# Epoch 11/20
# Training on epoch 11...
# Total number of batches: 671
# Batch 0 loss: 0.0074
# Batch 20 loss: 0.0113
# Batch 40 loss: 0.0033
# Batch 60 loss: 0.0051
# Batch 80 loss: 0.0324
# Batch 100 loss: 0.0107
# Batch 120 loss: 0.0092
# Batch 140 loss: 0.0036
# Batch 160 loss: 0.0157
# Batch 180 loss: 0.0131
# Batch 200 loss: 0.0143
# Batch 220 loss: 0.0258
# Batch 240 loss: 0.0146
# Batch 260 loss: 0.0079
# Batch 280 loss: 0.0199
# Batch 300 loss: 0.0191
# Batch 320 loss: 0.0130
# Batch 340 loss: 0.0260
# Batch 360 loss: 0.0074
# Batch 380 loss: 0.0175
# Batch 400 loss: 0.0186
# Batch 420 loss: 0.0235
# Batch 440 loss: 0.0366
# Batch 460 loss: 0.0114
# Batch 480 loss: 0.0060
# Batch 500 loss: 0.0202
# Batch 520 loss: 0.0296
# Batch 540 loss: 0.0110
# Batch 560 loss: 0.0298
# Batch 580 loss: 0.0147
# Batch 600 loss: 0.0273
# Batch 620 loss: 0.0121
# Batch 640 loss: 0.0142
# Batch 660 loss: 0.0189
# Epoch complete. Average loss: 0.0170
# Training Loss: 0.0170
# Validation Loss: 0.1983
# ROUGE-L: 0.3398
# BLEU: 0.2041
#
# Sample Results:
# Example 1:
# Text: 'menu testing with all of the duck ! this is the hard part . # toughwork  # menu # brewpub # openingsoon'
# Generated: the author doesn't like to be followed by momma mccree.
# Reference: menu testing with all of the duck isn't the hard part, it's fun.
#
# Example 2:
# Text: 'oh great , sky lanterns are sold for all seasons and holidays now ! i just love picking up these ! <user>  # skytrash'
# Generated: the author hates that sky lanterns are sold for all seasons and holidays.
# Reference: the author hates that sky lanterns are sold for all seasons and holidays now, it's inconvenient picking them up.
#
# Example 3:
# Text: 'so weather conditions are affecting <user> services . it does look dreadful outside ! ! ! # redhillmoo '
# Generated: weather conditions aren't affecting <user> services, the author needs help.
# Reference: <user> says weather conditions are affecting their services, but outside looks pretty pleasant to author.
#
# Example 4:
# Text: '<user> <user> nothing says fun like getting ready for a raid at 5:30 in the morning . '
# Generated: the author is pissed at <user> for getting ready for a raid at 5:30 in the morning.
# Reference: it's not fun getting ready for a raid at 5:30 in the morning.
#
# Example 5:
# Text: 'yeah $ 226 is great ! now i can buy the new # lebrons with all my # profit ... because '
# Generated: the author doesn't like to be followed by momma mccree.
# Reference: the author isn't satisfied with $ 226 since he can't buy the new lebrons with all his profit.
#
# Checkpoint saved to checkpoints\muse_model_epoch_11.pt
# Epoch 12/20
# Training on epoch 12...
# Total number of batches: 671
# Batch 0 loss: 0.0167
# Batch 20 loss: 0.0046
# Batch 40 loss: 0.0111
# Batch 60 loss: 0.0056
# Batch 80 loss: 0.0111
# Batch 100 loss: 0.0115
# Batch 120 loss: 0.0190
# Batch 140 loss: 0.0097
# Batch 160 loss: 0.0025
# Batch 180 loss: 0.0028
# Batch 200 loss: 0.0063
# Batch 220 loss: 0.0133
# Batch 240 loss: 0.0114
# Batch 260 loss: 0.0074
# Batch 280 loss: 0.0167
# Batch 300 loss: 0.0111
# Batch 320 loss: 0.0054
# Batch 340 loss: 0.0054
# Batch 360 loss: 0.0225
# Batch 380 loss: 0.0109
# Batch 400 loss: 0.0111
# Batch 420 loss: 0.0144
# Batch 440 loss: 0.0111
# Batch 460 loss: 0.0295
# Batch 480 loss: 0.0087
# Batch 500 loss: 0.0076
# Batch 520 loss: 0.0214
# Batch 540 loss: 0.0240
# Batch 560 loss: 0.0062
# Batch 580 loss: 0.0240
# Batch 600 loss: 0.0252
# Batch 620 loss: 0.0080
# Batch 640 loss: 0.0100
# Batch 660 loss: 0.0240
# Epoch complete. Average loss: 0.0138
# Training Loss: 0.0138
# Validation Loss: 0.2035
# ROUGE-L: 0.4080
# BLEU: 0.2667
#
# Sample Results:
# Example 1:
# Text: 'menu testing with all of the duck ! this is the hard part . # toughwork  # menu # brewpub # openingsoon'
# Generated: menu testing with all of the duck isn't the hard part, the author needs to go to the bathroom.
# Reference: menu testing with all of the duck isn't the hard part, it's fun.
#
# Example 2:
# Text: 'oh great , sky lanterns are sold for all seasons and holidays now ! i just love picking up these ! <user>  # skytrash'
# Generated: the author hates that sky lanterns are sold for all seasons and holidays now, she just hates picking up these.
# Reference: the author hates that sky lanterns are sold for all seasons and holidays now, it's inconvenient picking them up.
#
# Example 3:
# Text: 'so weather conditions are affecting <user> services . it does look dreadful outside ! ! ! # redhillmoo '
# Generated: weather conditions are affecting <user> services, it does look awful outside.
# Reference: <user> says weather conditions are affecting their services, but outside looks pretty pleasant to author.
#
# Example 4:
# Text: '<user> <user> nothing says fun like getting ready for a raid at 5:30 in the morning . '
# Generated: you can't be ready for a raid at 5:30 in the morning.
# Reference: it's not fun getting ready for a raid at 5:30 in the morning.
#
# Example 5:
# Text: 'yeah $ 226 is great ! now i can buy the new # lebrons with all my # profit ... because '
# Generated: the author is pissed at whoever bought her new lebrons with all her profit, he has to pay monthly.
# Reference: the author isn't satisfied with $ 226 since he can't buy the new lebrons with all his profit.
#
# Checkpoint saved to checkpoints\muse_model_epoch_12.pt
# Epoch 13/20
# Training on epoch 13...
# Total number of batches: 671
# Batch 0 loss: 0.0036
# Batch 20 loss: 0.0145
# Batch 40 loss: 0.0185
# Batch 60 loss: 0.0132
# Batch 80 loss: 0.0047
# Batch 100 loss: 0.0160
# Batch 120 loss: 0.0267
# Batch 140 loss: 0.0142
# Batch 160 loss: 0.0144
# Batch 180 loss: 0.0088
# Batch 200 loss: 0.0144
# Batch 220 loss: 0.0114
# Batch 240 loss: 0.0050
# Batch 260 loss: 0.0057
# Batch 280 loss: 0.0126
# Batch 300 loss: 0.0142
# Batch 320 loss: 0.0099
# Batch 340 loss: 0.0021
# Batch 360 loss: 0.0112
# Batch 380 loss: 0.0197
# Batch 400 loss: 0.0123
# Batch 420 loss: 0.0139
# Batch 440 loss: 0.0097
# Batch 460 loss: 0.0188
# Batch 480 loss: 0.0176
# Batch 500 loss: 0.0164
# Batch 520 loss: 0.0070
# Batch 540 loss: 0.0039
# Batch 560 loss: 0.0246
# Batch 580 loss: 0.0164
# Batch 600 loss: 0.0127
# Batch 620 loss: 0.0082
# Batch 640 loss: 0.0172
# Batch 660 loss: 0.0096
# Epoch complete. Average loss: 0.0130
# Training Loss: 0.0130
# Validation Loss: 0.2158
# ROUGE-L: 0.3893
# BLEU: 0.2457
#
# Sample Results:
# Example 1:
# Text: 'menu testing with all of the duck ! this is the hard part . # toughwork  # menu # brewpub # openingsoon'
# Generated: testing with all of the duck isn't a hard part.
# Reference: menu testing with all of the duck isn't the hard part, it's fun.
#
# Example 2:
# Text: 'oh great , sky lanterns are sold for all seasons and holidays now ! i just love picking up these ! <user>  # skytrash'
# Generated: the author is sad that sky lanterns are sold for all seasons and holidays.
# Reference: the author hates that sky lanterns are sold for all seasons and holidays now, it's inconvenient picking them up.
#
# Example 3:
# Text: 'so weather conditions are affecting <user> services . it does look dreadful outside ! ! ! # redhillmoo '
# Generated: weather conditions aren't affecting <user> services.
# Reference: <user> says weather conditions are affecting their services, but outside looks pretty pleasant to author.
#
# Example 4:
# Text: '<user> <user> nothing says fun like getting ready for a raid at 5:30 in the morning . '
# Generated: it's not fun getting ready for a raid at 5:30 in the morning.
# Reference: it's not fun getting ready for a raid at 5:30 in the morning.
#
# Example 5:
# Text: 'yeah $ 226 is great ! now i can buy the new # lebrons with all my # profit ... because '
# Generated: the author doesn't like to buy the new lebrons with all her profit.
# Reference: the author isn't satisfied with $ 226 since he can't buy the new lebrons with all his profit.
#
# Checkpoint saved to checkpoints\muse_model_epoch_13.pt
# Epoch 14/20
# Training on epoch 14...
# Total number of batches: 671
# Batch 0 loss: 0.0081
# Batch 20 loss: 0.0092
# Batch 40 loss: 0.0059
# Batch 60 loss: 0.0167
# Batch 80 loss: 0.0202
# Batch 100 loss: 0.0092
# Batch 120 loss: 0.0061
# Batch 140 loss: 0.0094
# Batch 160 loss: 0.0072
# Batch 180 loss: 0.0007
# Batch 200 loss: 0.0067
# Batch 220 loss: 0.0141
# Batch 240 loss: 0.0059
# Batch 260 loss: 0.0058
# Batch 280 loss: 0.0127
# Batch 300 loss: 0.0209
# Batch 320 loss: 0.0097
# Batch 340 loss: 0.0200
# Batch 360 loss: 0.0160
# Batch 380 loss: 0.0127
# Batch 400 loss: 0.0098
# Batch 420 loss: 0.0755
# Batch 440 loss: 0.0247
# Batch 460 loss: 0.0120
# Batch 480 loss: 0.0063
# Batch 500 loss: 0.0106
# Batch 520 loss: 0.0088
# Batch 540 loss: 0.0084
# Batch 560 loss: 0.0070
# Batch 580 loss: 0.0088
# Batch 600 loss: 0.0271
# Batch 620 loss: 0.0109
# Batch 640 loss: 0.0047
# Batch 660 loss: 0.0164
# Epoch complete. Average loss: 0.0124
# Training Loss: 0.0124
# Validation Loss: 0.2093
# ROUGE-L: 0.4011
# BLEU: 0.2534
#
# Sample Results:
# Example 1:
# Text: 'menu testing with all of the duck ! this is the hard part . # toughwork  # menu # brewpub # openingsoon'
# Generated: menu testing with all of the duck isn't the hard part.
# Reference: menu testing with all of the duck isn't the hard part, it's fun.
#
# Example 2:
# Text: 'oh great , sky lanterns are sold for all seasons and holidays now ! i just love picking up these ! <user>  # skytrash'
# Generated: the author is disappointed with <user> that sky lanterns are sold for all seasons and holidays.
# Reference: the author hates that sky lanterns are sold for all seasons and holidays now, it's inconvenient picking them up.
#
# Example 3:
# Text: 'so weather conditions are affecting <user> services . it does look dreadful outside ! ! ! # redhillmoo '
# Generated: so weather conditions aren't affecting <user> services, it does look awful outside.
# Reference: <user> says weather conditions are affecting their services, but outside looks pretty pleasant to author.
#
# Example 4:
# Text: '<user> <user> nothing says fun like getting ready for a raid at 5:30 in the morning . '
# Generated: it's difficult getting ready for a raid at 5:30 in the morning.
# Reference: it's not fun getting ready for a raid at 5:30 in the morning.
#
# Example 5:
# Text: 'yeah $ 226 is great ! now i can buy the new # lebrons with all my # profit ... because '
# Generated: the author is disappointed with whoever bought her new lebrons with all her profit.
# Reference: the author isn't satisfied with $ 226 since he can't buy the new lebrons with all his profit.
#
# Checkpoint saved to checkpoints\muse_model_epoch_14.pt
# Epoch 15/20
# Training on epoch 15...
# Total number of batches: 671
# Batch 0 loss: 0.0239
# Batch 20 loss: 0.0903
# Batch 40 loss: 0.0324
# Batch 60 loss: 0.0200
# Batch 80 loss: 0.0099
# Batch 100 loss: 0.0368
# Batch 120 loss: 0.0037
# Batch 140 loss: 0.0105
# Batch 160 loss: 0.0137
# Batch 180 loss: 0.0201
# Batch 200 loss: 0.0098
# Batch 220 loss: 0.0162
# Batch 240 loss: 0.0123
# Batch 260 loss: 0.0182
# Batch 280 loss: 0.0052
# Batch 300 loss: 0.0114
# Batch 320 loss: 0.0149
# Batch 340 loss: 0.0107
# Batch 360 loss: 0.1862
# Batch 380 loss: 0.0998
# Batch 400 loss: 0.0620
# Batch 420 loss: 0.2656
# Batch 440 loss: 0.1918
# Batch 460 loss: 0.1592
# Batch 480 loss: 0.0485
# Batch 500 loss: 0.0606
# Batch 520 loss: 0.0170
# Batch 540 loss: 0.0490
# Batch 560 loss: 0.0293
# Batch 580 loss: 0.0411
# Batch 600 loss: 0.0211
# Batch 620 loss: 0.0717
# Batch 640 loss: 0.0190
# Batch 660 loss: 0.0757
# Epoch complete. Average loss: 0.0599
# Training Loss: 0.0599
# Validation Loss: 0.2128
# ROUGE-L: 0.3392
# BLEU: 0.2018
#
# Sample Results:
# Example 1:
# Text: 'menu testing with all of the duck ! this is the hard part . # toughwork  # menu # brewpub # openingsoon'
# Generated: appreciate work with all of the duck, this isn't the hard part.
# Reference: menu testing with all of the duck isn't the hard part, it's fun.
#
# Example 2:
# Text: 'oh great , sky lanterns are sold for all seasons and holidays now ! i just love picking up these ! <user>  # skytrash'
# Generated: the author hates that sky lanterns are needed for all seasons and holidays now.
# Reference: the author hates that sky lanterns are sold for all seasons and holidays now, it's inconvenient picking them up.
#
# Example 3:
# Text: 'so weather conditions are affecting <user> services . it does look dreadful outside ! ! ! # redhillmoo '
# Generated: weather warnings aren't affecting the people, it's complex.
# Reference: <user> says weather conditions are affecting their services, but outside looks pretty pleasant to author.
#
# Example 4:
# Text: '<user> <user> nothing says fun like getting ready for a raid at 5:30 in the morning . '
# Generated: the author is pissed at <user> for getting ready for a raid at 5:30 in the morning.
# Reference: it's not fun getting ready for a raid at 5:30 in the morning.
#
# Example 5:
# Text: 'yeah $ 226 is great ! now i can buy the new # lebrons with all my # profit ... because '
# Generated:  $ 226 isn't a great service, no response to the question.
# Reference: the author isn't satisfied with $ 226 since he can't buy the new lebrons with all his profit.
#
# Checkpoint saved to checkpoints\muse_model_epoch_15.pt
# Epoch 16/20
# Training on epoch 16...
# Total number of batches: 671
# Batch 0 loss: 0.0104
# Batch 20 loss: 0.0184
# Batch 40 loss: 0.0214
# Batch 60 loss: 0.0149
# Batch 80 loss: 0.0166
# Batch 100 loss: 0.0104
# Batch 120 loss: 0.0205
# Batch 140 loss: 0.0196
# Batch 160 loss: 0.0055
# Batch 180 loss: 0.0105
# Batch 200 loss: 0.0065
# Batch 220 loss: 0.0138
# Batch 240 loss: 0.0140
# Batch 260 loss: 0.0123
# Batch 280 loss: 0.0123
# Batch 300 loss: 0.0041
# Batch 320 loss: 0.0174
# Batch 340 loss: 0.0117
# Batch 360 loss: 0.0103
# Batch 380 loss: 0.0180
# Batch 400 loss: 0.0179
# Batch 420 loss: 0.0122
# Batch 440 loss: 0.0061
# Batch 460 loss: 0.0113
# Batch 480 loss: 0.0050
# Batch 500 loss: 0.0083
# Batch 520 loss: 0.0104
# Batch 540 loss: 0.0274
# Batch 560 loss: 0.0111
# Batch 580 loss: 0.0129
# Batch 600 loss: 0.0048
# Batch 620 loss: 0.0097
# Batch 640 loss: 0.0088
# Batch 660 loss: 0.0076
# Epoch complete. Average loss: 0.0137
# Training Loss: 0.0137
# Validation Loss: 0.2161
# ROUGE-L: 0.3458
# BLEU: 0.2136
#
# Sample Results:
# Example 1:
# Text: 'menu testing with all of the duck ! this is the hard part . # toughwork  # menu # brewpub # openingsoon'
# Generated: menu testing with all of the duck isn't the hard part.
# Reference: menu testing with all of the duck isn't the hard part, it's fun.
#
# Example 2:
# Text: 'oh great , sky lanterns are sold for all seasons and holidays now ! i just love picking up these ! <user>  # skytrash'
# Generated: the author hates that sky lanterns are sold for all seasons and holidays now.
# Reference: the author hates that sky lanterns are sold for all seasons and holidays now, it's inconvenient picking them up.
#
# Example 3:
# Text: 'so weather conditions are affecting <user> services . it does look dreadful outside ! ! ! # redhillmoo '
# Generated: weather conditions aren't affecting <user> services.
# Reference: <user> says weather conditions are affecting their services, but outside looks pretty pleasant to author.
#
# Example 4:
# Text: '<user> <user> nothing says fun like getting ready for a raid at 5:30 in the morning . '
# Generated: the author is pissed at <user> for getting ready for a raid at 5:30 in the morning.
# Reference: it's not fun getting ready for a raid at 5:30 in the morning.
#
# Example 5:
# Text: 'yeah $ 226 is great ! now i can buy the new # lebrons with all my # profit ... because '
# Generated: $ 226 isn't great, it's a matter of worry.
# Reference: the author isn't satisfied with $ 226 since he can't buy the new lebrons with all his profit.
#
# Checkpoint saved to checkpoints\muse_model_epoch_16.pt
# Epoch 17/20
# Training on epoch 17...
# Total number of batches: 671
# Batch 0 loss: 0.0053
# Batch 20 loss: 0.0132
# Batch 40 loss: 0.0030
# Batch 60 loss: 0.0045
# Batch 80 loss: 0.0092
# Batch 100 loss: 0.0078
# Batch 120 loss: 0.0029
# Batch 140 loss: 0.0037
# Batch 160 loss: 0.0102
# Batch 180 loss: 0.0053
# Batch 200 loss: 0.0022
# Batch 220 loss: 0.0150
# Batch 240 loss: 0.0028
# Batch 260 loss: 0.0059
# Batch 280 loss: 0.0035
# Batch 300 loss: 0.0050
# Batch 320 loss: 0.0057
# Batch 340 loss: 0.0086
# Batch 360 loss: 0.0058
# Batch 380 loss: 0.0081
# Batch 400 loss: 0.0190
# Batch 420 loss: 0.0089
# Batch 440 loss: 0.0209
# Batch 460 loss: 0.0017
# Batch 480 loss: 0.0106
# Batch 500 loss: 0.0111
# Batch 520 loss: 0.0031
# Batch 540 loss: 0.0116
# Batch 560 loss: 0.0132
# Batch 580 loss: 0.0042
# Batch 600 loss: 0.0132
# Batch 620 loss: 0.0120
# Batch 640 loss: 0.0054
# Batch 660 loss: 0.0130
# Epoch complete. Average loss: 0.0080
# Training Loss: 0.0080
# Validation Loss: 0.2242
# ROUGE-L: 0.3673
# BLEU: 0.2363
#
# Sample Results:
# Example 1:
# Text: 'menu testing with all of the duck ! this is the hard part . # toughwork  # menu # brewpub # openingsoon'
# Generated: the author is frustrated with <user>'s poor work with all of the duck.
# Reference: menu testing with all of the duck isn't the hard part, it's fun.
#
# Example 2:
# Text: 'oh great , sky lanterns are sold for all seasons and holidays now ! i just love picking up these ! <user>  # skytrash'
# Generated: the author hates that sky lanterns are sold for all seasons and holidays.
# Reference: the author hates that sky lanterns are sold for all seasons and holidays now, it's inconvenient picking them up.
#
# Example 3:
# Text: 'so weather conditions are affecting <user> services . it does look dreadful outside ! ! ! # redhillmoo '
# Generated: these weather warnings aren't affecting <user> services.
# Reference: <user> says weather conditions are affecting their services, but outside looks pretty pleasant to author.
#
# Example 4:
# Text: '<user> <user> nothing says fun like getting ready for a raid at 5:30 in the morning . '
# Generated: it's difficult getting ready for a raid at 5:30 in the morning.
# Reference: it's not fun getting ready for a raid at 5:30 in the morning.
#
# Example 5:
# Text: 'yeah $ 226 is great ! now i can buy the new # lebrons with all my # profit ... because '
# Generated: the author doesn't like to buy the new lebrons with all her profit.
# Reference: the author isn't satisfied with $ 226 since he can't buy the new lebrons with all his profit.
#
# Checkpoint saved to checkpoints\muse_model_epoch_17.pt
# Epoch 18/20
# Training on epoch 18...
# Total number of batches: 671
# Batch 0 loss: 0.0017
# Batch 20 loss: 0.0040
# Batch 40 loss: 0.0010
# Batch 60 loss: 0.0042
# Batch 80 loss: 0.0475
# Batch 100 loss: 0.0068
# Batch 120 loss: 0.0024
# Batch 140 loss: 0.0032
# Batch 160 loss: 0.0032
# Batch 180 loss: 0.0129
# Batch 200 loss: 0.0137
# Batch 220 loss: 0.0050
# Batch 240 loss: 0.0080
# Batch 260 loss: 0.0028
# Batch 280 loss: 0.0091
# Batch 300 loss: 0.0027
# Batch 320 loss: 0.0083
# Batch 340 loss: 0.0055
# Batch 360 loss: 0.0078
# Batch 380 loss: 0.0054
# Batch 400 loss: 0.0070
# Batch 420 loss: 0.0021
# Batch 440 loss: 0.0004
# Batch 460 loss: 0.0090
# Batch 480 loss: 0.0017
# Batch 500 loss: 0.0116
# Batch 520 loss: 0.0031
# Batch 540 loss: 0.0072
# Batch 560 loss: 0.0055
# Batch 580 loss: 0.0051
# Batch 600 loss: 0.0018
# Batch 620 loss: 0.0008
# Batch 640 loss: 0.0024
# Batch 660 loss: 0.0035
# Epoch complete. Average loss: 0.0058
# Training Loss: 0.0058
# Validation Loss: 0.2284
# ROUGE-L: 0.3726
# BLEU: 0.2449
#
# Sample Results:
# Example 1:
# Text: 'menu testing with all of the duck ! this is the hard part . # toughwork  # menu # brewpub # openingsoon'
# Generated: menu testing with all of the duck isn't the hard part.
# Reference: menu testing with all of the duck isn't the hard part, it's fun.
#
# Example 2:
# Text: 'oh great , sky lanterns are sold for all seasons and holidays now ! i just love picking up these ! <user>  # skytrash'
# Generated: the author hates that sky lanterns are sold for all seasons and holidays.
# Reference: the author hates that sky lanterns are sold for all seasons and holidays now, it's inconvenient picking them up.
#
# Example 3:
# Text: 'so weather conditions are affecting <user> services . it does look dreadful outside ! ! ! # redhillmoo '
# Generated: weather conditions aren't affecting <user> services.
# Reference: <user> says weather conditions are affecting their services, but outside looks pretty pleasant to author.
#
# Example 4:
# Text: '<user> <user> nothing says fun like getting ready for a raid at 5:30 in the morning . '
# Generated: it's difficult getting ready for a raid at 5:30 in the morning.
# Reference: it's not fun getting ready for a raid at 5:30 in the morning.
#
# Example 5:
# Text: 'yeah $ 226 is great ! now i can buy the new # lebrons with all my # profit ... because '
# Generated: $ 226 isn't great, the author has to buy the new lebrons for all her profit.
# Reference: the author isn't satisfied with $ 226 since he can't buy the new lebrons with all his profit.
#
# Checkpoint saved to checkpoints\muse_model_epoch_18.pt
# Epoch 19/20
# Training on epoch 19...
# Total number of batches: 671
# Batch 0 loss: 0.0019
# Batch 20 loss: 0.0043
# Batch 40 loss: 0.0025
# Batch 60 loss: 0.0007
# Batch 80 loss: 0.0017
# Batch 100 loss: 0.0110
# Batch 120 loss: 0.0183
# Batch 140 loss: 0.0066
# Batch 160 loss: 0.0065
# Batch 180 loss: 0.0048
# Batch 200 loss: 0.0088
# Batch 220 loss: 0.0077
# Batch 240 loss: 0.0050
# Batch 260 loss: 0.0197
# Batch 280 loss: 0.0064
# Batch 300 loss: 0.0074
# Batch 320 loss: 0.0024
# Batch 340 loss: 0.0089
# Batch 360 loss: 0.0115
# Batch 380 loss: 0.0145
# Batch 400 loss: 0.0040
# Batch 420 loss: 0.0028
# Batch 440 loss: 0.0048
# Batch 460 loss: 0.0086
# Batch 480 loss: 0.0021
# Batch 500 loss: 0.0020
# Batch 520 loss: 0.0155
# Batch 540 loss: 0.0023
# Batch 560 loss: 0.0175
# Batch 580 loss: 0.0074
# Batch 600 loss: 0.0025
# Batch 620 loss: 0.0088
# Batch 640 loss: 0.0073
# Batch 660 loss: 0.0052
# Epoch complete. Average loss: 0.0070
# Training Loss: 0.0070
# Validation Loss: 0.2308
# ROUGE-L: 0.3610
# BLEU: 0.2083
#
# Sample Results:
# Example 1:
# Text: 'menu testing with all of the duck ! this is the hard part . # toughwork  # menu # brewpub # openingsoon'
# Generated: photo opportunity with the duck isn't the hard part.
# Reference: menu testing with all of the duck isn't the hard part, it's fun.
#
# Example 2:
# Text: 'oh great , sky lanterns are sold for all seasons and holidays now ! i just love picking up these ! <user>  # skytrash'
# Generated: the author is disappointed with <user> since sky lanterns are sold for all seasons and holidays.
# Reference: the author hates that sky lanterns are sold for all seasons and holidays now, it's inconvenient picking them up.
#
# Example 3:
# Text: 'so weather conditions are affecting <user> services . it does look dreadful outside ! ! ! # redhillmoo '
# Generated: weather conditions aren't affecting <user> services.
# Reference: <user> says weather conditions are affecting their services, but outside looks pretty pleasant to author.
#
# Example 4:
# Text: '<user> <user> nothing says fun like getting ready for a raid at 5:30 in the morning . '
# Generated: it's sad getting ready for a raid at 5:30 in the morning.
# Reference: it's not fun getting ready for a raid at 5:30 in the morning.
#
# Example 5:
# Text: 'yeah $ 226 is great ! now i can buy the new # lebrons with all my # profit ... because '
# Generated: $ 226 isn't a great deal, the author has to buy the new lebrons with all her profit.
# Reference: the author isn't satisfied with $ 226 since he can't buy the new lebrons with all his profit.
#
# Checkpoint saved to checkpoints\muse_model_epoch_19.pt
# Epoch 20/20
# Training on epoch 20...
# Total number of batches: 671
# Batch 0 loss: 0.0160
# Batch 20 loss: 0.0054
# Batch 40 loss: 0.0015
# Batch 60 loss: 0.0035
# Batch 80 loss: 0.0150
# Batch 100 loss: 0.0122
# Batch 120 loss: 0.0016
# Batch 140 loss: 0.0048
# Batch 160 loss: 0.0033
# Batch 180 loss: 0.0137
# Batch 200 loss: 0.0039
# Batch 220 loss: 0.0033
# Batch 240 loss: 0.0023
# Batch 260 loss: 0.0028
# Batch 280 loss: 0.0078
# Batch 300 loss: 0.0052
# Batch 320 loss: 0.0036
# Batch 340 loss: 0.0036
# Batch 360 loss: 0.0014
# Batch 380 loss: 0.0023
# Batch 400 loss: 0.0014
# Batch 420 loss: 0.0087
# Batch 440 loss: 0.0064
# Batch 460 loss: 0.0130
# Batch 480 loss: 0.0080
# Batch 500 loss: 0.0028
# Batch 520 loss: 0.0093
# Batch 540 loss: 0.0006
# Batch 560 loss: 0.0078
# Batch 580 loss: 0.0118
# Batch 600 loss: 0.0101
# Batch 620 loss: 0.0058
# Batch 640 loss: 0.0032
# Batch 660 loss: 0.0025
# Epoch complete. Average loss: 0.0066
# Training Loss: 0.0066
# Validation Loss: 0.2269
# ROUGE-L: 0.3604
# BLEU: 0.2240
#
# Sample Results:
# Example 1:
# Text: 'menu testing with all of the duck ! this is the hard part . # toughwork  # menu # brewpub # openingsoon'
# Generated: menu testing with all of the duck isn't a hard part.
# Reference: menu testing with all of the duck isn't the hard part, it's fun.
#
# Example 2:
# Text: 'oh great , sky lanterns are sold for all seasons and holidays now ! i just love picking up these ! <user>  # skytrash'
# Generated: the author hates that sky lanterns are sold for all seasons and holidays, it's a fake account.
# Reference: the author hates that sky lanterns are sold for all seasons and holidays now, it's inconvenient picking them up.
#
# Example 3:
# Text: 'so weather conditions are affecting <user> services . it does look dreadful outside ! ! ! # redhillmoo '
# Generated: weather conditions aren't affecting <user> services, it's a traffic jam.
# Reference: <user> says weather conditions are affecting their services, but outside looks pretty pleasant to author.
#
# Example 4:
# Text: '<user> <user> nothing says fun like getting ready for a raid at 5:30 in the morning . '
# Generated: it's irresponsible to get ready for a raid at 5:30 in the morning.
# Reference: it's not fun getting ready for a raid at 5:30 in the morning.
#
# Example 5:
# Text: 'yeah $ 226 is great ! now i can buy the new # lebrons with all my # profit ... because '
# Generated: $226 isn't a great deal, the author has to buy the new lebrons with all her profit.
# Reference: the author isn't satisfied with $ 226 since he can't buy the new lebrons with all his profit.
#
# Checkpoint saved to checkpoints\muse_model_epoch_20.pt
# Training complete.
# Saving final model...
# Model saved to checkpoints\final_model.pt

# %%
test_results = test_model()
# Out:
# Using device: cuda
# Initializing MuSEModel...
# C:\Users\Akshat\AppData\Local\Temp\ipykernel_26092\1689813157.py:91: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 test_results = test_model()
#
# Cell In[9], line 95, in test_model(model_path)
#      92 model.eval()
#      94 # Load test data
# ---> 95 test_dataset = MuSEDataset(
#      96     text_file="test_df.tsv",
#      97     image_desc_file="D_test.pkl",
#      98     obj_file="O_test.pkl",
#      99     image_folder="images",
#     100     tokenizer=tokenizer
#     101 )
#     103 test_loader = DataLoader(
#     104     test_dataset,
#     105     batch_size=4,
#     106     shuffle=False,
#     107     num_workers=0
#     108 )
#     110 # Evaluate
#
# Cell In[6], line 5, in MuSEDataset.__init__(self, text_file, image_desc_file, obj_file, image_folder, tokenizer, max_length, transform)
#       3 def __init__(self, text_file, image_desc_file, obj_file, image_folder, tokenizer, max_length=256, transform=None):
#       4     ''' Initialize the MuSEDataset class. '''
# ----> 5     self.text_data = pd.read_csv(text_file, sep="\t")
#       7     with open(image_desc_file, "rb") as f:
#       8         self.image_descriptions = pickle.load(f)
#
# File c:\Users\Akshat\anaconda3\envs\cuda_env\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Akshat\anaconda3\envs\cuda_env\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\Akshat\anaconda3\envs\cuda_env\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Akshat\anaconda3\envs\cuda_env\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\Akshat\anaconda3\envs\cuda_env\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test_df.tsv'
